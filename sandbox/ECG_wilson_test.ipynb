# %%
import sys
import os
sys.path.append(os.path.join(os.getcwd(), '..', 'src'))

import ecg
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 5
#       2 import os
#       3 sys.path.append(os.path.join(os.getcwd(), '..', 'src'))
# ----> 5 import ecg
#
# File t:\laupodteam\AIOS\Bram\production\TimEx\sandbox\..\src\ecg.py:6
#       4 import numpy as np
#       5 import neurokit2 as nk
# ----> 6 from catch22 import catch22_all
#       7 from tsfresh.feature_extraction import extract_features
#       8 import pandas as pd
#
# ModuleNotFoundError: No module named 'catch22'
